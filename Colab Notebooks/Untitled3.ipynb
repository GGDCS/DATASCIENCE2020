# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cf424f8e-713c-4f0e-82c0-822a33340bde" name="files[]" multiple disabled />
#      <output id="result-cf424f8e-713c-4f0e-82c0-822a33340bde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Heart_Disease_Prediction.csv to Heart_Disease_Prediction.csv
# ...

# %%
data = pd.read_csv("Heart_Disease_Prediction.csv")

# %%
data.head()
# Out:
#    Age  Sex  Chest pain type  ...  Number of vessels fluro  Thallium  Heart Disease
# 0   70    1                4  ...                        3         3       Presence
# 1   67    0                3  ...                        0         7        Absence
# 2   57    1                2  ...                        0         7       Presence
# 3   64    1                4  ...                        1         7        Absence
# 4   74    0                2  ...                        1         3        Absence
#
# [5 rows x 14 columns]

# %%
data.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
data.Age
data.Heart Disease
# Out:
#   File "<ipython-input-19-7b3a0ef307ee>", line 2
#     data.Heart Disease
#                      ^
# SyntaxError: invalid syntax

# %%
data.HeartDisease[data.HeartDisease=='Presence'] = 1
data.HeartDisease[data.HeartDisease=='Absence'] = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-91bc001fde77> in <module>()
# ----> 1 data.HeartDisease[data.HeartDisease=='Presence'] = 1
#       2 data.HeartDisease[data.HeartDisease=='Absence'] = 0
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'HeartDisease'
