# %%
# !pip install nltk
import nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
text = "hi garaham, how are you? Nice climate, trivandrum is awesome. You shouldn't eat non vegetarian "

# %%
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['hi garaham, how are you?', 'Nice climate, trivandrum is awesome.', "You shouldn't eat non vegetarian"]

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['hi', 'garaham', ',', 'how', 'are', 'you', '?', 'Nice', 'climate', ',', 'trivandrum', 'is', 'awesome', '.', 'You', 'should', "n't", 'eat', 'non', 'vegetarian']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 19 samples and 20 outcomes>

# %%
fdist.most_common(2)
# Out:
# [(',', 2), ('hi', 1)]

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative = False)
plt.show()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# /usr/local/lib/python3.6/dist-packages/nltk/data.py in find(resource_name, paths)
#     672     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 673     raise LookupError(resource_not_found)
#     674
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-32-03d11e2356c8> in <module>()
#       1 from nltk.corpus import stopwords
# ----> 2 stop_words = set(stopwords.words("english"))
#
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# /usr/local/lib/python3.6/dist-packages/nltk/data.py in find(resource_name, paths)
#     671     sep = '*' * 70
#     672     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 673     raise LookupError(resource_not_found)
#     674
#     675
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/lib/nltk_data'
# **********************************************************************

# %%
nltk.download("stopwords")

from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'myself', 'been', 'having', 'too', 'weren', 'those', 'had', 'can', 'not', 'was', 'didn', 'mightn', 'below', 'both', 'at', 'haven', 'doing', 'the', 'me', 'herself', 'again', "couldn't", 'why', 'shan', 'how', "doesn't", 'yourselves', 'hadn', 'we', "needn't", 'for', 'under', 'don', 'off', 'themselves', 'during', 'all', 'ma', 'did', 'am', "you've", "hadn't", 'himself', 'her', "should've", 'because', 'any', 'up', 'most', 'they', "you're", 'aren', "you'd", 'no', 'very', 'd', 'y', 'but', 'yours', 'ours', 'of', "hasn't", 'hers', 'what', 't', 'or', "that'll", 'just', 'than', 'should', 'o', 'does', "wouldn't", 'him', 'own', 'these', 'on', 'if', 'there', 'to', "mustn't", "wasn't", "haven't", 'that', 'were', 'wasn', "shan't", 'be', 'out', 'over', 'do', 'are', 'some', 'it', 'he', 'through', 'which', 'their', 'whom', "isn't", "mightn't", 'theirs', 'i', 'down', 'against', 'my', 'have', "weren't", 'mustn', 'wouldn', 'shouldn', 'our', 'she', 'with', "won't", 'from', 'above', 'hasn', 'only', 'will', 'who', 'as', 'its', 'won', "don't", 'them', 'between', "didn't", 'isn', 'other', 'couldn', 'll', 'here', "aren't", 'such', 'more', 'then', 'now', 've', 'm', 'by', 'your', 'in', 'being', 'nor', 'same', 's', 'ourselves', "you'll", 'itself', 'is', 'after', 're', 'while', 'further', 'and', 'ain', 'doesn', 'his', 'has', 'about', 'until', 'an', 'where', "shouldn't", 'when', 'few', "it's", 'before', 'once', 'so', 'this', 'yourself', 'each', "she's", 'a', 'you', 'needn', 'into'}

# %%
#removing stopwords

filtered_sent=[]
for w in tokenized_text:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_text)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['hi garaham, how are you?', 'Nice climate, trivandrum is awesome.', "You shouldn't eat non vegetarian"]
# Filterd Sentence: ['hi garaham, how are you?', 'Nice climate, trivandrum is awesome.', "You shouldn't eat non vegetarian"]

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['hi garaham, how are you?', 'Nice climate, trivandrum is awesome.', "You shouldn't eat non vegetarian"]
# Stemmed Sentence: ['hi garaham, how are you?', 'nice climate, trivandrum is awesome.', "you shouldn't eat non vegetarian"]
