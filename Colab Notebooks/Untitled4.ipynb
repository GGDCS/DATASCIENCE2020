# %%
data.head
# Out:
# <bound method NDFrame.head of            Suburb             Address  Rooms  ... CouncilArea  Lattitude Longtitude
# 0      Abbotsford       68 Studley St    2.0  ...       Yarra   -37.8014   144.9958
# 1      Abbotsford        85 Turner St    2.0  ...       Yarra   -37.7996   144.9984
# 2      Abbotsford     25 Bloomburg St    2.0  ...       Yarra   -37.8079   144.9934
# 3      Abbotsford  18/659 Victoria St    3.0  ...       Yarra   -37.8114   145.0116
# 4      Abbotsford        5 Charles St    3.0  ...       Yarra   -37.8093   144.9944
# ...           ...                 ...    ...  ...         ...        ...        ...
# 14241    Seaholme        3/1 James Av    2.0  ...         NaN  -37.67413  144.94731
# 14242         NaN                 NaN    NaN  ...         NaN  -37.67513  144.96976
# 14243         NaN                 NaN    NaN  ...         NaN        NaN  144.96944
# 14244         NaN                 NaN    NaN  ...         NaN  -37.78466        NaN
# 14245         NaN                 NaN    NaN  ...         NaN        NaN  144.93829
#
# [14246 rows x 19 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of            Suburb             Address  Rooms  ... CouncilArea  Lattitude Longtitude
# 0      Abbotsford       68 Studley St    2.0  ...       Yarra   -37.8014   144.9958
# 1      Abbotsford        85 Turner St    2.0  ...       Yarra   -37.7996   144.9984
# 2      Abbotsford     25 Bloomburg St    2.0  ...       Yarra   -37.8079   144.9934
# 3      Abbotsford  18/659 Victoria St    3.0  ...       Yarra   -37.8114   145.0116
# 4      Abbotsford        5 Charles St    3.0  ...       Yarra   -37.8093   144.9944
# ...           ...                 ...    ...  ...         ...        ...        ...
# 14241    Seaholme        3/1 James Av    2.0  ...         NaN  -37.67413  144.94731
# 14242         NaN                 NaN    NaN  ...         NaN  -37.67513  144.96976
# 14243         NaN                 NaN    NaN  ...         NaN        NaN  144.96944
# 14244         NaN                 NaN    NaN  ...         NaN  -37.78466        NaN
# 14245         NaN                 NaN    NaN  ...         NaN        NaN  144.93829
#
# [14246 rows x 19 columns]>

# %%
data.dtypes
# Out:
# Suburb           object
# Address          object
# Rooms           float64
# Type             object
# Price           float64
# Method           object
# SellerG          object
# Date             object
# Distance        float64
# Postcode        float64
# Bedroom2        float64
# Bathroom        float64
# Car             float64
# Landsize        float64
# BuildingArea    float64
# YearBuilt       float64
# CouncilArea      object
# Lattitude        object
# Longtitude       object
# dtype: object

# %%
print("skew is:",data.Price.skew())
plt.hist(data.Price,color = 'blue')
plt.show()
# Out:
# skew is: 2.175345424335199
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
target = np.log(data.Price)
print("skew is ",target.skew())
plt.hist(target, color = 'blue')
plt.show()
# Out:
# skew is  0.20791384004357696
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
numeric_features = data.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Rooms           float64
# Price           float64
# Distance        float64
# Postcode        float64
# Bedroom2        float64
# Bathroom        float64
# Car             float64
# Landsize        float64
# BuildingArea    float64
# YearBuilt       float64
# dtype: object
