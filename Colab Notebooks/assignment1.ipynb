# %%
import numpy as np
import pandas as pd

# %%
# data

data = {"sales" : [651,762,856,1063,1190,1298,1421,1440,1518],
"advertising" : [23,26,30,34,43,48,52,57,58]}

# %%
data = pd.DataFrame(data)

# %%
data.corr()
# Out:
#                 sales  advertising
# sales        1.000000     0.988288
# advertising  0.988288     1.000000

# %%
X = data["advertising"]

# %%
y = data["sales"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit_transform(X)
sc.transform(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-792027d6fe07> in <module>()
# ----> 1 sc.fit_transform(X)
#       2 sc.transform(y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# ...
