# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-394cf44a-e84a-416c-bff1-e988999dfdba" name="files[]" multiple disabled />
#      <output id="result-394cf44a-e84a-416c-bff1-e988999dfdba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Houseprice.csv to Houseprice (1).csv
# ...

# %%
data = pd.read_csv('Houseprice.csv')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
data.tail()
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [5 rows x 81 columns]

# %%
#skew correction bring values near to zero, left tailed->exponential
print("skew is:",data.SalePrice.skew())
plt.hist(data.SalePrice,color = 'blue')
plt.show()
# Out:
# skew is: 1.8828757597682129

# %%
#make the distribution symmetric
data.SalePrice.skew()
# Out:
# 1.8828757597682129

# %%
#it is right tailed so apply log
target = np.log(data.SalePrice)
print("skew is ",target.skew())
plt.hist(target, color = 'blue')
plt.show()
# Out:
# skew is  0.12133506220520406

# %%
#NUMERIC FEATURES
numeric_features = data.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
#relationship between features( skew corrected target variable)
plt.scatter(x=data['GrLivArea'],y= target)
plt.ylabel("Sale Price")
plt.xlabel("Above ground living area sqft ")
plt.show()

# %%
plt.scatter(x=data['GarageArea'],y= target)
plt.ylabel("Sale Price")
plt.xlabel("Garage area ")
plt.show()

# %%
data = data[data['GarageArea']<1200]
target = np.log(data.SalePrice)

# %%
plt.scatter(x = data['GarageArea'],y = target)
plt.xlim(-200,1600) #same scale
plt.ylabel("Sale Price")
plt.xlabel("Garage area ")
plt.show()

# %%
categoricals = data.select_dtypes(exclude=[np.number])
categoricals.dtypes
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# ...

# %%
#DEALING WITH MISSING DATA  
data1 = data.select_dtypes(include= [np.number]).interpolate()

# %%
#check if all the columns have zero null value
sum(data1.isnull().sum() != 0)
# Out:
# 0

# %%
#assign features to X and Targets to y
#sale price is the target and we log transform the sales price to improve performance.
# EVERYTHING OTHER THAN THE SALESPRICE ARE FEATURES
y = np.log(data.SalePrice)
x = data1.drop(['SalePrice', 'Id'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,random_state=42, test_size = .33)

# %%
#Build a linear model
#linear regression model first initialise the model

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model = lr.fit(X_train, y_train)
fit() missing 1 required positional argument: 'y'

# %%
predictions = model.predict(X_test)

# %%
#evaluate performance and visualise results
from sklearn.metrics import mean_squared_error
print("RMSE is : \n", mean_squared_error(y_test,predictions))
# Out:
# RMSE is :
#  0.01819705754249938

# %%
#visualise result
#if predicted values are identical to the actual values , graph would be straight line  y=x

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.75, color = 'b')
#alpha to show the overlapping data
plt.xlabel("Predicted price")
plt.ylabel("actual price")
plt.title("linear regression")
plt.show()

# %%
print("hi")
